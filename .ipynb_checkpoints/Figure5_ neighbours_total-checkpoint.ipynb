# %% [markdown]
# # Multi-Variate EOF and candidates selection
# On va d'abbord récupérer les composants principaux des EOFs individuelles des différentes variables.
# Puis on concatenate les matrices de PCs d'EOF individuelle tronquée sur une même dimension :
#
# - Dimension 1 : les différents membres de l'ensemble (n = 102)
#
# - Dimension 2 : les PCs d'EOFs individuelles tronquées pour les différentes variables (n = n_tronquée * n_variables). Ici n_tronquée = 5 modes et n_variables = 5 variables.

# %% [markdown]
# # Jupyter settings

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# !jt -fs 20 -ofs 20 - dfs 20 -nfs 20
# Out:
# <style>.container { width:100% !important; }</style>
# usage: jt [-h] [-l] [-t THEME] [-f MONOFONT] [-fs MONOSIZE] [-nf NBFONT]
#           [-nfs NBFONTSIZE] [-tf TCFONT] [-tfs TCFONTSIZE] [-dfs DFFONTSIZE]
#           [-ofs OUTFONTSIZE] [-mathfs MATHFONTSIZE] [-m MARGINS]
#           [-cursw CURSORWIDTH] [-cursc CURSORCOLOR] [-cellw CELLWIDTH]
#           [-lineh LINEHEIGHT] [-altp] [-altmd] [-altout] [-P] [-T] [-N] [-kl]
#           [-vim] [-r] [-dfonts]
# jt: error: unrecognized arguments: - dfs 20

# %% [markdown]
# # Import Module

# %%
# Computational modules 
# %matplotlib inline
import xarray as xr
import glob
import os
import numpy as np
import netCDF4
from netCDF4 import Dataset
import pandas as pd
import re
from array import array
from pylab import *
#import geopandas
from eofs.xarray import Eof
from eofs.multivariate.standard import MultivariateEof

# Plotting modules 
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import pandas.plotting
import matplotlib.ticker as ticker
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import BoundaryNorm

# Scikit-learn
from sklearn import linear_model
from sklearn.linear_model import LassoCV, LassoLarsCV, LassoLarsIC
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.neural_network import MLPRegressor
import scipy 
from scipy.optimize import minimize
from scipy.optimize import dual_annealing
from sklearn.decomposition import PCA

# %% [markdown]
# # Settings

# %% [markdown]
# ### Variables

# %%
variables = ['tas', 'pr', 'SW', 'LW', 'psl']

# %% [markdown]
# ### Paths

# %%
path_official='/data/scratch/globc/peatier/CMIP6/CNRM-CM6-1/CFMIP/amip/'
path_PPE='/data/scratch/globc/peatier/CNRM-CM6-1_PPE/'
path_files='/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/'

# %% [markdown]
# ### List of members

# %%
nb_p_list = ['p311', 'p312', 'p314', 'p316',
                    'p317', 'p319', 'p320', 'p321', 'p322', 'p324', 'p325', 'p326', 
                    'p329', 'p330', 'p331', 'p332', 'p335', 'p336', 'p337' ,'p338', 
                    'p340', 'p341', 'p343', 'p344', 'p346', 'p347', 'p348', 'p349', 
                    'p350', 'p353', 'p355', 'p357', 'p359', 'p360', 
                    'p361', 'p363', 'p365', 'p367', 'p368', 'p369', 
                    'p372', 'p373', 'p374', 'p375', 'p376', 'p378', 'p381', 'p382', 
                    'p384', 'p386', 'p388', 'p389', 'p391', 'p392', 'p393', 
                    'p394', 'p395', 'p396', 'p398', 'p399', 'p400', 'p404', 
                    'p406', 'p407', 'p409', 'p410', 'p411', 'p412',
                    'p414','p416',
                    'p413','p419','p424','p426','p428','p421','p423',
                    'p425','p427','p429','p430','p436','p438','p431','p433',
                    'p442','p446','p443','p445','p447',
                    'p452','p454','p456','p458','p457','p459',
                    'p460','p465','p467','p469',
                    'p470','p471']

len(nb_p_list)
# Out:
# 102

# %% [markdown]
# # Functions

# %%
def load_monthly_clim(path, filename, variables) :
    
    file = xr.open_mfdataset(path+filename,combine='by_coords')
    df=file[variables].to_dataframe()
    
    # Compute Climatological Annual Cycle :
    df1=df.reset_index(level=['time', 'lat', 'lon'])
    df1['year']=pd.DatetimeIndex(df1['time']).year
    df1['month']=pd.DatetimeIndex(df1['time']).month
    
    #list_ind = []
    #cpt=0
    #for i in df1['year'] : 
    #    if i>1981 :
    #        list_ind.append(cpt)
    #        cpt+=1
    #    else : 
    #        cpt+=1
            
    #df2 = df1.drop(list_ind)
    df_mean=df1.groupby(['month', 'lat', 'lon']).mean()
    df_mean=df_mean.drop(columns='year')
    
    return df_mean

# %% [markdown]
# # Get data : obs
#
# On récupère directement les data projetées sur la base EOF du PPE, de la variable correspondante. (U_obs)

# %% [markdown]
# ## Temperature : BEST data

# %%
var = 'tas'
U_obs = {}
U_obs[var] = np.load(path_files+'npy/CNRMppe_decomposition_U_obs_'+var+'.npy')
U_obs[var]
# Out:
# array([-35.30081 , -39.041958,  62.09356 ,  44.23777 , -57.485878],
#       dtype=float32)

# %% [markdown]
# ## Precipitation : GPCP

# %%
var = 'pr'
U_obs[var] = np.load(path_files+'npy/CNRMppe_decomposition_U_obs_'+var+'.npy')
U_obs[var]
# Out:
# array([118.08318081, -75.96825392, -10.60677721,  47.43860722,
#        -77.10519667])

# %% [markdown]
# ## SW : CERES data

# %%
var = 'SW'
U_obs[var] = np.load(path_files+'npy/CNRMppe_decomposition_U_obs_'+var+'.npy')
U_obs[var]
# Out:
# array([  923.1411 , -1032.1937 ,  -561.6581 ,   336.58038,    87.92828],
#       dtype=float32)

# %% [markdown]
# ## LW : CERES data

# %%
var = 'LW'
U_obs[var] = np.load(path_files+'npy/CNRMppe_decomposition_U_obs_'+var+'.npy')
U_obs[var]
# Out:
# array([  27.709879,  388.57288 ,  821.90375 ,  -89.317825, -232.15962 ],
#       dtype=float32)

# %% [markdown]
# ## Pressure : NCEP

# %%
var = 'psl'
U_obs[var] = np.load(path_files+'npy/CNRMppe_decomposition_U_obs_'+var+'.npy')
U_obs[var]
# Out:
# array([ 17916.693,  10520.148,  22854.988, -17135.393,  -9038.122],
#       dtype=float32)

# %% [markdown]
# # Multi-variate EOF
#
# On récupère les PC des 5 premiers modes chaque EOF (correspondant à chacune des 5 variables), on les normalise par la moyenne d'ensemble des pc, puis on fait l'EOF multi-variate.

# %%
pc_PPE = {}

for var in variables : 
    pc = []
    for j in range(1,6, 1) :
        tmp = np.load(path_files+'npy/CNRMppe_decomposition_EOF'+str(j)+'pc_'+str(var)+'.npy')
        pc.append(tmp)
    pc_PPE[str(var)] = pc

# %%
# On normalize également les PCs en enlevant la moyenne d'ensemble et divisant par l'écart-type : 

df_pc_PPE_multi = pd.DataFrame(pc_PPE['tas'][0], columns = ['tas - EOF 1'])
for var in variables : 
    for j in range(1,6, 1) :
        tmp = pc_PPE[var][j-1]
        tmp_mean = pc_PPE[var][j-1].mean()
        tmp_std = pc_PPE[var][j-1].std()
        df_pc_PPE_multi[var+' - EOF '+str(j)] = (tmp - tmp_mean)/tmp_std
df_pc_PPE_multi
# Out:
#      tas - EOF 1  tas - EOF 2  tas - EOF 3  tas - EOF 4  tas - EOF 5  \
# 0      -0.744489    -1.673261     0.853752     0.042470    -1.548252
# 1       0.307994     0.724050    -0.675794    -0.422953     1.644540
# 2       1.687606    -0.849755     0.109793     0.104752    -0.670095
# 3       0.529297    -1.642946    -0.151469    -0.657469     1.692734
# 4       0.688822     0.156021     0.255692    -0.848135    -1.852867
# ..           ...          ...          ...          ...          ...
# 97      0.644371    -0.737653    -2.033379    -0.570061     0.835376
# 98     -1.469338     0.986660    -2.543679     1.143452     0.296719
# 99     -0.435799     1.090412    -1.237641     1.773306     1.054716
# 100     1.373877    -0.031661    -1.635394     0.188671     0.496991
# 101     0.973989     1.051724    -0.251283     1.464317     1.052779
#
#      pr - EOF 1  pr - EOF 2  pr - EOF 3  pr - EOF 4  pr - EOF 5  ...  \
# 0     -0.636492    1.232000    0.718669   -0.586214    0.898512  ...
# 1     -0.827055   -0.398111    0.512189   -0.352457   -0.154650  ...
# 2     -0.328727   -0.188585    0.640106   -0.573277    1.764534  ...
# 3     -1.831913    0.058098    0.743906   -0.234946   -0.333954  ...
# 4      1.006320    0.079897    1.966904    1.738780    1.958663  ...
# ..          ...         ...         ...         ...         ...  ...
# 97    -1.372081   -0.487129    0.044131    0.002247    0.483887  ...
# 98     0.951342   -1.034900   -0.808521   -0.805487   -0.030553  ...
# 99     0.386599   -0.216890    0.014379   -0.619977   -0.253288  ...
# 100    0.504464   -0.264270    1.252899   -0.424700   -0.240763  ...
# 101    1.036102   -2.017067   -1.190527    0.432126   -1.179354  ...
#
#      LW - EOF 1  LW - EOF 2  LW - EOF 3  LW - EOF 4  LW - EOF 5  psl - EOF 1  \
# 0     -0.740630    0.149068   -0.210366   -0.392028    2.001104    -0.684246
# 1      0.301492   -0.345761   -1.048826    0.371093   -0.330773     0.072250
# 2      1.811387    0.572975   -0.217129    0.530132    0.623857    -0.107168
# 3      0.518465   -0.880733   -1.821710    0.067228   -0.740356    -0.997948
# 4      0.652091   -0.164390    0.214764    1.577974    0.698172    -0.658479
# ..          ...         ...         ...         ...         ...          ...
# 97    -0.298226    0.179859   -1.061704    0.351855   -0.889566    -0.138683
# 98    -0.434170   -2.133588    0.798420    1.574823   -1.617914     1.088275
# 99     0.102120   -0.798628    0.347578    0.315628   -0.183916     1.760727
# 100    0.724235   -0.368940   -0.054803    0.724481    0.174744     0.924846
# 101    0.094695    1.633545    1.519070   -0.237533   -2.467371     1.730313
#
#      psl - EOF 2  psl - EOF 3  psl - EOF 4  psl - EOF 5
# 0      -1.937335     0.125499     1.939961     1.921937
# 1       0.977608    -0.909045     0.671314    -0.360227
# 2       0.308263    -0.507369     0.474761    -0.173217
# 3       1.333931    -0.777306     0.555326    -0.196770
# 4      -0.829874     1.739421     0.762109    -0.691717
# ..           ...          ...          ...          ...
# 97      1.674873     0.497884    -0.481120    -1.554459
# 98      0.673505     1.526290     0.082438    -0.765884
# 99      1.368530     0.388749     1.007138     0.344169
# 100     1.336779    -0.370561     0.398990    -0.339809
# 101     0.387995    -0.185463    -0.885896    -2.154661
#
# [102 rows x 25 columns]

# %%
xr_pc_PPE_multi = xr.DataArray(df_pc_PPE_multi.values, dims = ['time', 'var - EOF nb'])
xr_pc_PPE_multi
# Out:
# <xarray.DataArray (time: 102, var - EOF nb: 25)>
# array([[-0.74448889, -1.67326057,  0.85375196, ...,  0.12549919,
#          1.93996143,  1.92193687],
#        [ 0.30799404,  0.72405022, -0.67579436, ..., -0.90904528,
#          0.67131424, -0.36022729],
#        [ 1.6876055 , -0.84975493,  0.10979337, ..., -0.50736922,
#          0.47476071, -0.17321669],
#        ...,
#        [-0.43579945,  1.09041238, -1.23764086, ...,  0.38874912,
#          1.00713849,  0.34416884],
#        [ 1.37387657, -0.03166063, -1.63539433, ..., -0.3705613 ,
#          0.39899036, -0.33980888],
#        [ 0.97398949,  1.05172396, -0.25128341, ..., -0.1854627 ,
#         -0.88589621, -2.1546607 ]])
# Dimensions without coordinates: time, var - EOF nb

# %%
# Create an EOF solver to do the EOF analysis. 
solver = Eof(xr_pc_PPE_multi, center=False)

# %%
pc_multi = solver.pcs(npcs=100, pcscaling=0)

# %%
len(pc_multi)
# Out:
# 102

# %%
varFrac = solver.varianceFraction(neigs=100)

# %%
tmp=0
for var in varFrac[0:5] :
    tmp = tmp + var
tmp
# Out:
# <xarray.DataArray 'variance_fractions' ()>
# array(0.70447726)
# Coordinates:
#     mode     int64 4

# %% [markdown]
# # Emulation

# %% [markdown]
# ### Evaluation du skill de l'émulateur pour l'EOF multi-variables

# %%
X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
y = pc_multi[:,0]

X_train = X[0:80]
y_train = y[0:80]
X_test = X[80:]
y_test = y[80:]
#LHS = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_param_standard.npy")
param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

# Let's use the model equation : 
X_df = pd.DataFrame(data=X)
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
R = regr.intercept_
Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

N=len(y_train)
tmp = [0]*N
y_pred = [0]*N
i=0
Ycpt=0
while i<N:
        
    tmp[i] = Coeffs.values*X_train[i]
    y_pred[i] = tmp[i].sum()+R
    i+=1

# %%
df_train = pd.DataFrame(y_train, columns = ['y_train'])
df_train['pred'] = y_pred
#df_train

# %%
df_OS = pd.DataFrame(y_test, columns = ['y_test'])
df_OS['y_pred'] = y_pred
#df_OS

# %%
r_train = np.corrcoef(df_train['y_train'], df_train['pred'])
r_test = np.corrcoef(df_OS['y_test'], df_OS['y_pred'])
print(r_train[0,1], r_test[0,1])
# Out:
# 0.959637742633119 0.7972109914557133

# %% [markdown]
# #### Figure

# %%
plt.figure(figsize=(8, 5))
    

ax = plt.gca()
#ax2 = ax.twinx()

#df_train.plot(kind='scatter', x='test', y='ej', color = 'black', alpha=1, ax=ax)
df_train.plot(kind='scatter', x='y_train', y='pred', color = 'blue', alpha=1, ax=ax)
df_OS.plot(kind='scatter', x='y_test', y='y_pred', color = 'red', alpha=1, ax=ax)
ax.text(3.5,-4.5, 'r = 0.95', color = 'blue', fontsize=15)
ax.text(3.5,-3.7,'r = 0.79', color = 'red', fontsize=15)

#ax.axhline(0, color='k', alpha=0.5)
#ax.set_ylim(0, 1.1)
ax.set_xlabel('PC values', size = 20)
ax.set_ylabel('Emulated PC values', size = 20)
ax.set_title('Multi-variate EOF', fontsize=20, 
             fontweight = 'bold')
#ax.set_xscale('log')
ax.tick_params(axis='y', which='major', labelsize=20)
ax.tick_params(axis='x', which='major', labelsize=20)

plt.xlim([-5, 5])
plt.ylim([-5, 5])

# Save la figure .................
figname = 'emulator_skill_EOF1_multi-variate.png'
plt.savefig("/data/home/globc/peatier/figures/"+figname, 
            orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %% [markdown]
# ### Prediction de 100 000 points

# %%
def MultiLinReg_pred(LHS, X ,y, param_names) :

    LHS_df = pd.DataFrame(LHS)

    lhs = LHS_df.values
    #LHS_df

    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    N=len(LHS_df.values)
    tmp = [0]*N
    y_pred = [0]*N
    i=0
    Ycpt=0
    while i<N:
        
        tmp[i] = Coeffs.values*LHS_df.iloc[i]
        y_pred[i] = tmp[i].sum()+R
        i+=1

    #y_pred
    #members = arange(102,100102,1)
    #DFYpred = pd.DataFrame([y_pred, members], index=["y_pred", "members"]).transpose()
    return y_pred

# %%
X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
LHS = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_param_standard.npy")
param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

pc = {}
for i in range(0,5, 1) :
    EOF_nb = i+1
    y = pc_multi[:,i]
    pc['pc'+str(EOF_nb)] = MultiLinReg_pred(LHS, X ,y, param_names)

# %%
df_pc = pd.DataFrame(pc)
df_pc
# Out:
#             pc1       pc2       pc3       pc4       pc5
# 0      1.780764  1.160987  0.178360  0.257798  0.963431
# 1      1.958757  1.928710 -0.252674  2.728716  0.690692
# 2     -0.513111 -1.615790  0.219469 -0.917624 -1.475661
# 3     -0.528796 -0.081274  2.515726 -0.085407  0.326419
# 4     -0.181189  2.548021 -1.303523 -0.495930  2.531455
# ...         ...       ...       ...       ...       ...
# 99995 -0.090941 -0.876570 -3.085562  1.411169 -1.289160
# 99996 -0.239487 -2.710770  0.063331  2.119142  0.995861
# 99997  0.936955  0.852268  1.420371 -0.478404 -2.047254
# 99998  4.424868 -1.273558  3.189935  1.526909  0.003104
# 99999 -0.093171  0.094794  2.206592  0.935712  0.798845
#
# [100000 rows x 5 columns]

# %% [markdown]
# ## Precipitation

# %%
var = 'pr'

X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
LHS = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_param_standard.npy")
param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

pc = {}
for i in range(0,5, 1) :
    EOF_nb = i+1
    y = np.load(file=path_files+'npy/CNRMppe_decomposition_EOF'+str(EOF_nb)+'pc_'+var+'.npy')
    pc['pc'+str(EOF_nb)] = MultiLinReg_pred(LHS, X ,y, param_names)

# %%
U_obs_tmp = U_obs[var]
pc1 = pc['pc1']
pc2 = pc['pc2']
pc3 = pc['pc3']
pc4 = pc['pc4']
pc5 = pc['pc5']
df_pc_norm_pr = df_pc_U_obs_norm(pc1, pc2, pc3, pc4, pc5, U_obs_tmp)
df_pc_norm_pr
# Out:
#            EOF 1     EOF 2     EOF 3     EOF 4     EOF 5        hue  members
# 0       0.815625  1.143880  0.034966 -1.200654  0.176020  Emulation        0
# 1       1.364123  1.434325 -0.049599 -1.594676 -1.662170  Emulation        1
# 2      -0.650879 -0.783183  0.798443  0.564096  0.621642  Emulation        2
# 3      -0.179374  1.720167  1.225438 -1.238530 -0.259031  Emulation        3
# 4      -0.006124  1.100942 -1.285309  1.056337  0.399752  Emulation        4
# ...          ...       ...       ...       ...       ...        ...      ...
# 99996  -0.657286 -1.204536  1.920367 -2.311184  0.748079  Emulation    99996
# 99997   0.431699  0.336303  0.189741 -0.144746  0.074990  Emulation    99997
# 99998   2.718233 -0.045206  2.226921  0.341760 -0.825530  Emulation    99998
# 99999   0.198123  0.317767  0.177210 -0.905978  0.402844  Emulation    99999
# 100000  2.093762 -1.961149 -0.410788  2.272938 -3.864275      U_obs   100000
#
# [100001 rows x 7 columns]

# %% [markdown]
# ## SW

# %%
var = 'SW'

X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
LHS = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_param_standard.npy")
param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

pc = {}
for i in range(0,5, 1) :
    EOF_nb = i+1
    y = np.load(file=path_files+'npy/CNRMppe_decomposition_EOF'+str(EOF_nb)+'pc_'+var+'.npy')
    pc['pc'+str(EOF_nb)] = MultiLinReg_pred(LHS, X ,y, param_names)

# %%
U_obs_tmp = U_obs[var]
pc1 = pc['pc1']
pc2 = pc['pc2']
pc3 = pc['pc3']
pc4 = pc['pc4']
pc5 = pc['pc5']
df_pc_norm_SW = df_pc_U_obs_norm(pc1, pc2, pc3, pc4, pc5, U_obs_tmp)
df_pc_norm_SW
# Out:
#            EOF 1     EOF 2     EOF 3     EOF 4     EOF 5        hue  members
# 0       0.557532 -1.268085 -0.484612  1.023008 -0.405363  Emulation        0
# 1       0.450444  1.029145  0.144104  1.718509 -2.556682  Emulation        1
# 2      -0.880364 -1.384477 -0.731974 -0.593237  2.432492  Emulation        2
# 3       0.284548  0.565911 -0.986625 -0.110041 -1.338734  Emulation        3
# 4       0.563026 -0.851040  1.509907 -0.086762 -0.675769  Emulation        4
# ...          ...       ...       ...       ...       ...        ...      ...
# 99996  -0.567811  1.529362 -0.313275  0.619816  0.134345  Emulation    99996
# 99997  -0.853589 -1.600646 -1.020369  0.037008  0.086664  Emulation    99997
# 99998  -0.908291 -1.005534 -2.963143  0.556527 -2.192848  Emulation    99998
# 99999  -1.417522  0.769953 -0.809161  0.309152 -1.481946  Emulation    99999
# 100000  0.776953 -2.208778 -1.307544  1.294705  0.480207      U_obs   100000
#
# [100001 rows x 7 columns]

# %% [markdown]
# ## LW

# %%
var = 'LW'

X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
LHS = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_param_standard.npy")
param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

pc = {}
for i in range(0,5, 1) :
    EOF_nb = i+1
    y = np.load(file=path_files+'npy/CNRMppe_decomposition_EOF'+str(EOF_nb)+'pc_'+var+'.npy')
    pc['pc'+str(EOF_nb)] = MultiLinReg_pred(LHS, X ,y, param_names)

# %%
U_obs_tmp = U_obs[var]
pc1 = pc['pc1']
pc2 = pc['pc2']
pc3 = pc['pc3']
pc4 = pc['pc4']
pc5 = pc['pc5']
df_pc_norm_LW = df_pc_U_obs_norm(pc1, pc2, pc3, pc4, pc5, U_obs_tmp)
df_pc_norm_LW
# Out:
#            EOF 1     EOF 2     EOF 3     EOF 4     EOF 5        hue  members
# 0       0.615176  0.334781  1.151006 -1.099753  1.889475  Emulation        0
# 1      -1.028305 -0.999876  1.333746 -1.142377  1.736832  Emulation        1
# 2       0.222343 -0.323182 -0.595714  1.320959 -0.511575  Emulation        2
# 3       1.707563 -1.294240 -0.463327  0.185476  2.306480  Emulation        3
# 4       0.130621  1.467957  0.205761 -2.007420  1.413778  Emulation        4
# ...          ...       ...       ...       ...       ...        ...      ...
# 99996  -0.984711  1.139796 -0.016437  1.514330  0.321196  Emulation    99996
# 99997   0.196157 -1.365670  0.353939  0.494202  0.180002  Emulation    99997
# 99998  -0.480843 -0.954887  2.097388  2.870102  0.605114  Emulation    99998
# 99999  -1.161966  0.811975  0.167921  0.742691  1.742556  Emulation    99999
# 100000  0.042072  1.294992  2.992470 -0.579264 -2.151752      U_obs   100000
#
# [100001 rows x 7 columns]

# %% [markdown]
# ## Pressure

# %%
var = 'psl'

X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
LHS = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_param_standard.npy")
param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

pc = {}
for i in range(0,5, 1) :
    EOF_nb = i+1
    y = np.load(file=path_files+'npy/CNRMppe_decomposition_EOF'+str(EOF_nb)+'pc_'+var+'.npy')
    pc['pc'+str(EOF_nb)] = MultiLinReg_pred(LHS, X ,y, param_names)

# %%
U_obs_tmp = U_obs[var]
pc1 = pc['pc1']
pc2 = pc['pc2']
pc3 = pc['pc3']
pc4 = pc['pc4']
pc5 = pc['pc5']
df_pc_norm_psl = df_pc_U_obs_norm(pc1, pc2, pc3, pc4, pc5, U_obs_tmp)
df_pc_norm_psl
# Out:
#            EOF 1     EOF 2     EOF 3     EOF 4     EOF 5        hue  members
# 0       0.702449 -0.826699  0.075700 -0.459541  0.922797  Emulation        0
# 1       1.315605  0.772338  0.190934 -0.204856  1.876694  Emulation        1
# 2      -0.124028  0.155567 -0.993089 -1.197874 -1.183950  Emulation        2
# 3      -0.749473  2.064798  1.813223  1.234594  0.371155  Emulation        3
# 4       0.204201 -1.777210 -1.645963 -0.509169  1.755603  Emulation        4
# ...          ...       ...       ...       ...       ...        ...      ...
# 99996   1.253156  0.287291 -2.271388  2.339462 -1.150646  Emulation    99996
# 99997  -0.694421  0.181683  1.737652 -0.941017  0.539715  Emulation    99997
# 99998   2.532783 -1.366039  1.534761  2.314351  0.045159  Emulation    99998
# 99999  -0.610837 -1.675612  0.355638  2.259535  0.454245  Emulation    99999
# 100000  0.561397  1.677875  4.549704 -5.323344 -2.970562      U_obs   100000
#
# [100001 rows x 7 columns]

# %% [markdown]
# ## Multi-variate DataFrame

# %%
df_pc_norm_total = pd.DataFrame(df_pc_norm_tas['hue'],  columns=['hue'])
df_pc_norm_total['members'] = df_pc_norm_tas['members']
for i in range(1, 6, 1) :
    df_pc_norm_total['EOF '+str(i)] = df_pc_norm_tas['EOF '+str(i)] + df_pc_norm_pr['EOF '+str(i)] + df_pc_norm_SW['EOF '+str(i)] + df_pc_norm_LW['EOF '+str(i)] + df_pc_norm_psl['EOF '+str(i)]/len(variables)

df_pc_norm_total
# Out:
#               hue  members     EOF 1     EOF 2     EOF 3     EOF 4     EOF 5
# 0       Emulation        0  2.119841  0.748265  0.505329 -1.129121  2.129969
# 1       Emulation        1  0.503272  1.817134  0.261034  0.492321 -1.207994
# 2       Emulation        2 -1.672811 -3.139894 -2.212327  2.059902  2.160350
# 3       Emulation        3  2.815606 -0.469266 -1.551055 -1.589232  0.027579
# 4       Emulation        4  0.666218  1.976026  3.119865  0.480731  2.369573
# ...           ...      ...       ...       ...       ...       ...       ...
# 99996   Emulation    99996 -0.812996  1.590972  0.426001  1.592575  2.868663
# 99997   Emulation    99997 -2.192726 -1.999862 -1.299965 -1.344249 -1.218009
# 99998   Emulation    99998  2.685705  0.052486  0.451479  3.076409 -4.198854
# 99999   Emulation    99999 -1.956176  0.516310  0.192200  0.939773 -0.647928
# 100000      U_obs   100000  2.767238 -3.069596  3.797097  3.821040 -9.346509
#
# [100001 rows x 7 columns]

# %% [markdown]
# # $5\%$ best models selection

# %%
def Error_rj(pc, U_obs):
    rj_list = []
    for i in range(0,len(U_obs),1) :
        j=i+1
        diff = (pc[i]-U_obs[i])**2
        rj_list.append(diff)
    rj_E = sqrt(sum(rj_list)/(len(U_obs)))
    return rj_E

# %%
U_obs = df_pc_norm_total.iloc[100000].to_list()[2:7]
error = []
for i in range(0, len(df_pc_norm_total), 1) : 
    pc = df_pc_norm_total.iloc[i].to_list()[2:7] 
    E = Error_rj(pc, U_obs)
    error.append(E)
#error

# %%
df_pc_norm_total['Error'] = error
df_pc_norm_total
# Out:
#               hue  members     EOF 1     EOF 2     EOF 3     EOF 4     EOF 5  \
# 0       Emulation        0  2.119841  0.748265  0.505329 -1.129121  2.129969
# 1       Emulation        1  0.503272  1.817134  0.261034  0.492321 -1.207994
# 2       Emulation        2 -1.672811 -3.139894 -2.212327  2.059902  2.160350
# 3       Emulation        3  2.815606 -0.469266 -1.551055 -1.589232  0.027579
# 4       Emulation        4  0.666218  1.976026  3.119865  0.480731  2.369573
# ...           ...      ...       ...       ...       ...       ...       ...
# 99996   Emulation    99996 -0.812996  1.590972  0.426001  1.592575  2.868663
# 99997   Emulation    99997 -2.192726 -1.999862 -1.299965 -1.344249 -1.218009
# 99998   Emulation    99998  2.685705  0.052486  0.451479  3.076409 -4.198854
# 99999   Emulation    99999 -1.956176  0.516310  0.192200  0.939773 -0.647928
# 100000      U_obs   100000  2.767238 -3.069596  3.797097  3.821040 -9.346509
#
#            Error
# 0       6.033980
# 1       4.874940
# 2       6.186139
# 3       5.522886
# 4       5.979222
# ...          ...
# 99996   6.325816
# 99997   5.375469
# 99998   3.098388
# 99999   5.140654
# 100000  0.000000
#
# [100001 rows x 8 columns]

# %%
df_pc_norm_total_sort = df_pc_norm_total.sort_values(by=['Error'], ascending=False)
hue = ['Emulated members']*95000+['$5\%$ best performing models']*5000+['Observations']
df_pc_norm_total_sort['Legend'] = hue
df_pc_norm_total_sort
# Out:
#               hue  members      EOF 1     EOF 2     EOF 3     EOF 4     EOF 5  \
# 37162   Emulation    37162 -15.625202 -0.856876 -2.683719 -4.319861  0.575583
# 54106   Emulation    54106 -12.373247 -1.594433 -3.130299 -5.129103  3.727206
# 77379   Emulation    77379 -11.514301 -1.523461 -1.273509 -6.237970  4.141974
# 68074   Emulation    68074 -14.298024 -1.626902 -3.701115 -2.850983  1.175737
# 11036   Emulation    11036 -12.536832 -5.187832 -2.942327 -3.014319  3.657854
# ...           ...      ...        ...       ...       ...       ...       ...
# 21605   Emulation    21605   1.174697  0.699261  2.943400  5.237826 -6.067730
# 27460   Emulation    27460   2.583707 -3.789530  0.967049  3.815923 -4.926064
# 71284   Emulation    71284   1.731285 -1.406012  3.073093  2.302649 -4.777109
# 8900    Emulation     8900   3.399924 -2.485154  3.283082  6.437555 -5.688739
# 100000      U_obs   100000   2.767238 -3.069596  3.797097  3.821040 -9.346509
#
#             Error                        Legend
# 37162   10.487146              Emulated members
# 54106   10.299770              Emulated members
# 77379   10.150732              Emulated members
# 68074   10.047500              Emulated members
# 11036    9.999569              Emulated members
# ...           ...                           ...
# 21605    2.458738  $5\%$ best performing models
# 27460    2.370718  $5\%$ best performing models
# 71284    2.347331  $5\%$ best performing models
# 8900     2.060656  $5\%$ best performing models
# 100000   0.000000                  Observations
#
# [100001 rows x 9 columns]

# %% [markdown]
# # Selection of diverse model candidates (pair-wise distance maximisation)

# %%
def compute_distance(df, index_list) :
    distance = {}
    for index in index_list : 
        #print(index)
        point_index = df.loc[index]
        points = df[index+1:]
        diff = {}
        for i in range(1, 6, 1) :
            tmp = (points['EOF '+str(i)] - point_index['EOF '+str(i)])**2
            diff['EOF '+str(i)+' dist'] = tmp
        distance[index] = sqrt(diff['EOF 1 dist']+diff['EOF 2 dist']+diff['EOF 3 dist']+diff['EOF 4 dist']+diff['EOF 5 dist'])/5
    return distance

# %%
import random

def chose_drop_index(distance) :
    distance_df = pd.DataFrame(distance)
    test = pd.DataFrame(distance_df.min()).sort_values(by=0)
    test2 =  pd.DataFrame(test)
    index_drop = []
    for cpt in range(0,10,2) :
        index1 = test2.index.values.astype(int)[cpt]
        index2 = test2.index.values.astype(int)[cpt+1]
        #print(index1, index2)
        tmp = random.choice([index1, index2])
        index_drop.append(tmp)
    return index_drop

# %%
df_best_pc = df_pc_norm_total_sort[95000:100000].reset_index().drop('index', axis=1)
df_best_pc
# Out:
#             hue  members     EOF 1     EOF 2     EOF 3     EOF 4     EOF 5  \
# 0     Emulation    80237  4.313361 -1.271836  0.604714  1.048636 -1.549786
# 1     Emulation     3818 -2.003476 -0.679935  1.663814  3.320574 -2.203908
# 2     Emulation    18185  7.537771  0.374401  3.695386  1.811217 -2.592348
# 3     Emulation    56146  3.467180  0.264529  1.104579  3.263875 -1.276919
# 4     Emulation    33419  4.581457 -1.353343  1.052521  4.360363 -0.966537
# ...         ...      ...       ...       ...       ...       ...       ...
# 4995  Emulation    48883  3.105347 -0.830573  1.763285  2.412665 -4.942210
# 4996  Emulation    21605  1.174697  0.699261  2.943400  5.237826 -6.067730
# 4997  Emulation    27460  2.583707 -3.789530  0.967049  3.815923 -4.926064
# 4998  Emulation    71284  1.731285 -1.406012  3.073093  2.302649 -4.777109
# 4999  Emulation     8900  3.399924 -2.485154  3.283082  6.437555 -5.688739
#
#          Error                        Legend
# 0     4.105822  $5\%$ best performing models
# 1     4.105808  $5\%$ best performing models
# 2     4.105789  $5\%$ best performing models
# 3     4.105720  $5\%$ best performing models
# 4     4.105714  $5\%$ best performing models
# ...        ...                           ...
# 4995  2.475694  $5\%$ best performing models
# 4996  2.458738  $5\%$ best performing models
# 4997  2.370718  $5\%$ best performing models
# 4998  2.347331  $5\%$ best performing models
# 4999  2.060656  $5\%$ best performing models
#
# [5000 rows x 9 columns]

# %%
df = df_best_pc
index_list = list(range(0, len(df_best_pc), 1))
n = len(df)

while n > 5 :
    distance = compute_distance(df, index_list)
    #print(distance)
    index_drop = chose_drop_index(distance)
    df = df.drop(index_drop)
    for index in index_drop : 
        index_list.remove(index)
    #print(df)
    n = len(df)
    print(n)
df
# Out:
# 4950
# 4900
# 4850
# 4800
# 4750
# 4700
# 4650
# 4600
# 4550
# 4500
# 4450
# 4400
# 4350
# 4300
# 4250
# 4200
# 4150
# 4100
# 4050
# 4000
# 3950
# 3900
# 3850
# 3800
# 3750
# 3700
# 3650
# 3600
# 3550
# 3500
# 3450
# 3400
# 3350
# 3300
# 3250
# 3200
# 3150
# 3100
# 3050
# 3000
# 2950
# 2900
# 2850
# 2800
# 2750
# 2700
# 2650
# 2600
# 2550
# 2500
# 2450
# 2400
# 2350
# 2300
# 2250
# 2200
# 2150
# 2100
# 2050
# 2000
# 1950
# 1900
# 1850
# 1800
# 1750
# 1700
# 1650
# 1600
# 1550
# 1500
# 1450
# 1400
# 1350
# 1300
# 1250
# 1200
# 1150
# 1100
# 1050
# 1000
# 950
# 900
# 850
# 800
# 750
# 700
# 650
# 600
# 550
# 500
# 450
# 400
# 350
# 300
# 250
# 200
# 150
# 100
# 50
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-20ed7a860c7c> in <module>
#       6     distance = compute_distance(df, index_list)
#       7     #print(distance)
# ----> 8     index_drop = chose_drop_index(distance)
#       9     df = df.drop(index_drop)
#      10     for index in index_drop :
#
# <ipython-input-114-fb04ae910e8c> in chose_drop_index(distance)
#       7     index_drop = []
#       8     for cpt in range(0,100,2) :
# ----> 9         index1 = test2.index.values.astype(int)[cpt]
#      10         index2 = test2.index.values.astype(int)[cpt+1]
#      11         #print(index1, index2)
#
# IndexError: index 50 is out of bounds for axis 0 with size 50

# %%
while n > 5 :
    distance = compute_distance(df, index_list)
    #print(distance)
    index_drop = chose_drop_index(distance)
    df = df.drop(index_drop)
    for index in index_drop : 
        index_list.remove(index)
    #print(df)
    n = len(df)
    print(n)
df
# Out:
# 45
# 40
# 35
# 30
# 25
# 20
# 15
# 10
# 5
#             hue  members     EOF 1     EOF 2     EOF 3     EOF 4     EOF 5  \
# 4957  Emulation    80836  0.387763 -1.773963  1.257815  3.308797 -4.300215
# 4982  Emulation    80465  3.069628 -2.690799  2.832016  4.982172 -3.595478
# 4988  Emulation    12193  1.715497  0.500103  3.457512  3.553401 -4.867855
# 4993  Emulation    23486  3.779453  0.009268  1.330189  2.465274 -5.762634
# 4996  Emulation    21605  1.174697  0.699261  2.943400  5.237826 -6.067730
#
#          Error                        Legend
# 4957  2.811263  $5\%$ best performing models
# 4982  2.667917  $5\%$ best performing models
# 4988  2.611291  $5\%$ best performing models
# 4993  2.500875  $5\%$ best performing models
# 4996  2.458738  $5\%$ best performing models

# %%
test = df.reset_index()
test['Legend'].iloc[0]= 'test'
test
# Out:
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#    index        hue  members     EOF 1     EOF 2     EOF 3     EOF 4  \
# 0   4957  Emulation    80836  0.387763 -1.773963  1.257815  3.308797
# 1   4982  Emulation    80465  3.069628 -2.690799  2.832016  4.982172
# 2   4988  Emulation    12193  1.715497  0.500103  3.457512  3.553401
# 3   4993  Emulation    23486  3.779453  0.009268  1.330189  2.465274
# 4   4996  Emulation    21605  1.174697  0.699261  2.943400  5.237826
#
#       EOF 5     Error                   Legend
# 0 -4.300215  2.811263                     test
# 1 -3.595478  2.667917  Selection of candidates
# 2 -4.867855  2.611291  Selection of candidates
# 3 -5.762634  2.500875  Selection of candidates
# 4 -6.067730  2.458738  Selection of candidates

# %%
for i in range(0, len(df), 1) : 
    df['Legend'].iloc[i] = 'Candidate '+str(i+1)
df
# Out:
#             hue  members     EOF 1     EOF 2     EOF 3     EOF 4     EOF 5  \
# 4957  Emulation    80836  0.387763 -1.773963  1.257815  3.308797 -4.300215
# 4982  Emulation    80465  3.069628 -2.690799  2.832016  4.982172 -3.595478
# 4988  Emulation    12193  1.715497  0.500103  3.457512  3.553401 -4.867855
# 4993  Emulation    23486  3.779453  0.009268  1.330189  2.465274 -5.762634
# 4996  Emulation    21605  1.174697  0.699261  2.943400  5.237826 -6.067730
#
#          Error       Legend
# 4957  2.811263  Candidate 1
# 4982  2.667917  Candidate 2
# 4988  2.611291  Candidate 3
# 4993  2.500875  Candidate 4
# 4996  2.458738  Candidate 5

# %%
df_fig = df_pc_norm_total_sort.append(df)
df_fig
# Out:
#              hue  members      EOF 1     EOF 2     EOF 3     EOF 4     EOF 5  \
# 37162  Emulation    37162 -15.625202 -0.856876 -2.683719 -4.319861  0.575583
# 54106  Emulation    54106 -12.373247 -1.594433 -3.130299 -5.129103  3.727206
# 77379  Emulation    77379 -11.514301 -1.523461 -1.273509 -6.237970  4.141974
# 68074  Emulation    68074 -14.298024 -1.626902 -3.701115 -2.850983  1.175737
# 11036  Emulation    11036 -12.536832 -5.187832 -2.942327 -3.014319  3.657854
# ...          ...      ...        ...       ...       ...       ...       ...
# 4957   Emulation    80836   0.387763 -1.773963  1.257815  3.308797 -4.300215
# 4982   Emulation    80465   3.069628 -2.690799  2.832016  4.982172 -3.595478
# 4988   Emulation    12193   1.715497  0.500103  3.457512  3.553401 -4.867855
# 4993   Emulation    23486   3.779453  0.009268  1.330189  2.465274 -5.762634
# 4996   Emulation    21605   1.174697  0.699261  2.943400  5.237826 -6.067730
#
#            Error            Legend
# 37162  10.487146  Emulated members
# 54106  10.299770  Emulated members
# 77379  10.150732  Emulated members
# 68074  10.047500  Emulated members
# 11036   9.999569  Emulated members
# ...          ...               ...
# 4957    2.811263       Candidate 1
# 4982    2.667917       Candidate 2
# 4988    2.611291       Candidate 3
# 4993    2.500875       Candidate 4
# 4996    2.458738       Candidate 5
#
# [100006 rows x 9 columns]

# %% [markdown]
# # Figure

# %%
plt.figure(figsize=(15, 15))
    
variables = ['EOF 1', 'EOF 2', 'EOF 3', 'EOF 4', 'EOF 5']
p = ['lightgray', 'darkgray','darkred','navy', 'forestgreen', 'purple', 'darkred', 'pink']
m = ['.','.', '+', '^', '^', '^', '^', '^']
n = [-4,-3,-2,-1,0,1,2,3,4]
sns.pairplot(df_fig, vars=variables, hue="Legend", diag_kind='hist', 
             palette=p, 
             markers=m,
             plot_kws=dict(edgecolor=None, s=55), 
             diag_kws=dict(edgecolor='black', bins=n))

# Save figure ---------------
name_fig='Fig5_total.png'
plt.savefig("/data/home/globc/peatier/figures/"+name_fig, 
            orientation='portrait', bbox_inches='tight', pad_inches=0.1)
#----------------------------



plt.show()
